# %% [markdown]
# Grafici nel tempo, corso informatica 31-L

# %%
import matplotlib.pyplot as plt

studenti = ["bored", "happy", "bored", "bored", "happy", "bored"]
#dog = ["happy", "happy", "happy", "happy", "bored", "bored"]
activity = ["2015","2016", "2017","2018","2019","2020"]

fig, ax = plt.subplots()
#ax.plot(activity, dog, label="dog")
ax.plot(activity, studenti, label="studenti")
ax.legend()

plt.show()
